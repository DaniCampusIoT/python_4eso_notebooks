# %% [markdown]
# # Operadores y expresiones
#
# ## Objetivos
# - Operaciones aritméticas
# - División / // %
# - Potencias
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: / vs // vs %

# %%
a=17
b=5
print(a/b, a//b, a%b)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Calcula 25 + 17 y guarda el resultado.
# 2. Calcula 100 - 37 y guarda el resultado.
# 3. Calcula 12 * 8 y guarda el resultado.
# 4. Calcula 144 / 12 y muestra el resultado.
# 5. Calcula 144 // 12 y comenta diferencia con /.
# 6. Calcula 17 % 3 y comenta qué significa.
# 7. Pide n y muestra si es múltiplo de 5.
# 8. Convierte 367 segundos a minutos y segundos.
# 9. Pide base y altura y calcula área triángulo (b*h/2).
# 10. Calcula 3**4 y 4**3 y muestra ambos.

# %% [markdown]
# ### Ejercicio 1
# Calcula 25 + 17 y guarda el resultado.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Calcula 100 - 37 y guarda el resultado.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Calcula 12 * 8 y guarda el resultado.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Calcula 144 / 12 y muestra el resultado.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Calcula 144 // 12 y comenta diferencia con /.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Calcula 17 % 3 y comenta qué significa.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Pide n y muestra si es múltiplo de 5.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Convierte 367 segundos a minutos y segundos.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Pide base y altura y calcula área triángulo (b*h/2).

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Calcula 3**4 y 4**3 y muestra ambos.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: pide días y conviértelo a semanas + días restantes (// y %).

# %%
# Reto
# TODO
