# %% [markdown]
# # Booleanos y comparaciones
#
# ## Objetivos
# - Comparar valores
# - and/or/not
# - Expresiones lógicas
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: lógica

# %%
nota=6
faltas=2
print((nota>=5) and (faltas<10))

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Compara 10 y 20 con <.
# 2. Compara 15 y 15 con ==.
# 3. Pide dos números y muestra si son iguales.
# 4. Pide un número y muestra si está entre 1 y 100 (incluidos).
# 5. Pide una contraseña y muestra si len>=8.
# 6. Pide una nota y muestra si está en rango 0..10.
# 7. Crea `tiene_carnet` y `tiene_coche` y `puede_conducir` con and.
# 8. Crea `es_fin_de_semana` y muestra `not es_fin_de_semana`.
# 9. Pide un número y muestra si es par y >10.
# 10. Pide edad y muestra si NO es menor de edad (not).

# %% [markdown]
# ### Ejercicio 1
# Compara 10 y 20 con <.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Compara 15 y 15 con ==.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Pide dos números y muestra si son iguales.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Pide un número y muestra si está entre 1 y 100 (incluidos).

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Pide una contraseña y muestra si len>=8.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Pide una nota y muestra si está en rango 0..10.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Crea `tiene_carnet` y `tiene_coche` y `puede_conducir` con and.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Crea `es_fin_de_semana` y muestra `not es_fin_de_semana`.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Pide un número y muestra si es par y >10.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Pide edad y muestra si NO es menor de edad (not).

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: pide edad y autorización (sí/no). Puede si edad>=16 o (edad>=14 y autorización=True).

# %%
# Reto
# TODO
