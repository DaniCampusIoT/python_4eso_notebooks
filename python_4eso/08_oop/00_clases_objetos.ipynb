# %% [markdown]
# # Clases y objetos
#
# ## Objetivos
# - class
# - __init__
# - atributos
# - métodos
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: clase simple

# %%
class Alumno:
    def __init__(self, nombre):
        self.nombre = nombre
    def saludar(self):
        print('Hola, soy', self.nombre)

a = Alumno('Ana')
a.saludar()

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Crea una clase `Alumno` con atributo `nombre` en __init__.
# 2. Añade atributo `curso` y crea 2 alumnos distintos.
# 3. Añade método `presentacion()` que imprima nombre y curso.
# 4. Crea una clase `Rectangulo` con ancho y alto.
# 5. Añade método `area()` a Rectangulo.
# 6. Añade método `perimetro()` a Rectangulo.
# 7. Crea 2 rectángulos y compara sus áreas.
# 8. Crea una clase `Contador` con atributo `valor` inicial 0.
# 9. Añade método `incrementar()` y método `reset()`.
# 10. Crea una lista de objetos Alumno y recórrela llamando a presentacion().

# %% [markdown]
# ### Ejercicio 1
# Crea una clase `Alumno` con atributo `nombre` en __init__.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Añade atributo `curso` y crea 2 alumnos distintos.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Añade método `presentacion()` que imprima nombre y curso.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Crea una clase `Rectangulo` con ancho y alto.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Añade método `area()` a Rectangulo.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Añade método `perimetro()` a Rectangulo.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Crea 2 rectángulos y compara sus áreas.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Crea una clase `Contador` con atributo `valor` inicial 0.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Añade método `incrementar()` y método `reset()`.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Crea una lista de objetos Alumno y recórrela llamando a presentacion().

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: Alumno con lista de notas y media(); crea 3 alumnos y muestra quién tiene mejor media.

# %%
# Reto
# TODO
