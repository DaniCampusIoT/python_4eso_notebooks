# %% [markdown]
# # Tuplas y sets
#
# ## Objetivos
# - Tuplas (inmutables)
# - Sets (sin repetidos)
# - Uso práctico
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: eliminar repetidos

# %%
nums = [1, 2, 2, 3, 3, 3]
sin_repes = set(nums)
print(sin_repes)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Crea una tupla con (nombre, edad) e imprímela.
# 2. Accede al primer elemento de una tupla (índice 0).
# 3. Intenta modificar una tupla y explica en comentario qué pasa.
# 4. Crea un set con 5 números, incluyendo repetidos, y muestra el resultado.
# 5. Convierte una lista con repetidos a set y luego de nuevo a lista.
# 6. Comprueba si un elemento está dentro de un set usando `in`.
# 7. Crea un set de vocales y cuenta cuántas vocales tiene una palabra.
# 8. Crea dos sets y calcula la intersección.
# 9. Con los mismos sets, calcula la unión.
# 10. Con los mismos sets, calcula la diferencia (A - B).

# %% [markdown]
# ### Ejercicio 1
# Crea una tupla con (nombre, edad) e imprímela.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Accede al primer elemento de una tupla (índice 0).

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Intenta modificar una tupla y explica en comentario qué pasa.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Crea un set con 5 números, incluyendo repetidos, y muestra el resultado.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Convierte una lista con repetidos a set y luego de nuevo a lista.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Comprueba si un elemento está dentro de un set usando `in`.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Crea un set de vocales y cuenta cuántas vocales tiene una palabra.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Crea dos sets y calcula la intersección.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Con los mismos sets, calcula la unión.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Con los mismos sets, calcula la diferencia (A - B).

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: pide 10 palabras, guarda lista y set, muestra total, distintas y palabras únicas.

# %%
# Reto
# TODO
