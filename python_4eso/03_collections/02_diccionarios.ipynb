# %% [markdown]
# # Diccionarios
#
# ## Objetivos
# - key/value
# - get()
# - items()
# - Mini-CRUD
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: diccionario básico

# %%
capitales = {'España': 'Madrid', 'Francia': 'París'}
print(capitales['España'])
for pais, cap in capitales.items():
    print(pais, '→', cap)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Crea un diccionario con 3 países y sus capitales.
# 2. Accede a un valor por clave e imprímelo.
# 3. Añade una nueva entrada al diccionario.
# 4. Borra una clave (del) y muestra el diccionario resultante.
# 5. Recorre el diccionario con items() e imprime 'clave: valor'.
# 6. Comprueba si una clave existe usando `in`.
# 7. Usa get() con una clave que no existe y devuelve un valor por defecto.
# 8. Crea un diccionario alumno→nota con 5 alumnos y calcula la media de notas.
# 9. Encuentra el alumno con mejor nota recorriendo el diccionario.
# 10. Crea un diccionario de conteo de letras de una palabra (letra→frecuencia).

# %% [markdown]
# ### Ejercicio 1
# Crea un diccionario con 3 países y sus capitales.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Accede a un valor por clave e imprímelo.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Añade una nueva entrada al diccionario.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Borra una clave (del) y muestra el diccionario resultante.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Recorre el diccionario con items() e imprime 'clave: valor'.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Comprueba si una clave existe usando `in`.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Usa get() con una clave que no existe y devuelve un valor por defecto.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Crea un diccionario alumno→nota con 5 alumnos y calcula la media de notas.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Encuentra el alumno con mejor nota recorriendo el diccionario.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Crea un diccionario de conteo de letras de una palabra (letra→frecuencia).

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: mini-agenda CRUD (nombre→teléfono) evitando sobreescritura accidental con confirmación.

# %%
# Reto
# TODO
