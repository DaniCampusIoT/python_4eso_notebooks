# %% [markdown]
# # Listas
#
# ## Objetivos
# - Crear listas
# - Índices
# - append/pop
# - Recorrer listas
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: media de notas

# %%
notas = [6, 7, 5, 9]
media = sum(notas) / len(notas)
print('media:', media)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Crea una lista con 5 nombres y muestra el primero y el último.
# 2. Añade un nombre a la lista (append) y muestra la lista.
# 3. Elimina el último elemento (pop) y muestra qué se eliminó y la lista final.
# 4. Crea una lista de 5 números y calcula la suma recorriéndola con for.
# 5. Calcula la media de una lista de notas (sin usar sum).
# 6. Encuentra el máximo de una lista (sin usar max).
# 7. Cuenta cuántos números pares hay en una lista de números.
# 8. Dada una lista de palabras, crea otra lista con las longitudes de cada palabra.
# 9. Pide 5 números por input y guárdalos en una lista; luego imprime la lista.
# 10. Ordena una lista de números (usa sort) y muestra el menor y el mayor.

# %% [markdown]
# ### Ejercicio 1
# Crea una lista con 5 nombres y muestra el primero y el último.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Añade un nombre a la lista (append) y muestra la lista.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Elimina el último elemento (pop) y muestra qué se eliminó y la lista final.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Crea una lista de 5 números y calcula la suma recorriéndola con for.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Calcula la media de una lista de notas (sin usar sum).

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Encuentra el máximo de una lista (sin usar max).

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Cuenta cuántos números pares hay en una lista de números.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Dada una lista de palabras, crea otra lista con las longitudes de cada palabra.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Pide 5 números por input y guárdalos en una lista; luego imprime la lista.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Ordena una lista de números (usa sort) y muestra el menor y el mayor.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: pide notas hasta 'fin', guarda en lista y al final muestra media, max, min y nº de aprobados.

# %%
# Reto
# TODO
