# %% [markdown]
# # Comprehensions (listas)
#
# ## Objetivos
# - Patrón de comprehension
# - Filtro con if
# - Legibilidad
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: cuadrados y filtrado

# %%
cuadrados = [x*x for x in range(1, 11)]
pares = [x for x in range(1, 21) if x % 2 == 0]
print(cuadrados)
print(pares)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Crea una lista con los números del 1 al 10 usando comprehension.
# 2. Crea una lista con los cuadrados del 1 al 10 usando comprehension.
# 3. Crea una lista con los múltiplos de 3 entre 1 y 30 usando comprehension.
# 4. Dada una lista de números, crea otra con solo los pares usando comprehension.
# 5. Dada una lista de palabras, crea otra con solo las que tengan longitud >= 5.
# 6. Dada una lista de palabras, crea otra con las palabras en mayúsculas.
# 7. Crea una lista con las primeras letras de cada palabra de una lista.
# 8. Crea una lista con los números del 10 al 1 (descendente).
# 9. Crea una lista con los números del 1 al 50 que NO sean múltiplos de 5.
# 10. Crea una lista 1..20 y reemplaza impares por -1 (ternario).

# %% [markdown]
# ### Ejercicio 1
# Crea una lista con los números del 1 al 10 usando comprehension.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Crea una lista con los cuadrados del 1 al 10 usando comprehension.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Crea una lista con los múltiplos de 3 entre 1 y 30 usando comprehension.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Dada una lista de números, crea otra con solo los pares usando comprehension.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Dada una lista de palabras, crea otra con solo las que tengan longitud >= 5.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Dada una lista de palabras, crea otra con las palabras en mayúsculas.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Crea una lista con las primeras letras de cada palabra de una lista.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Crea una lista con los números del 10 al 1 (descendente).

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Crea una lista con los números del 1 al 50 que NO sean múltiplos de 5.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Crea una lista 1..20 y reemplaza impares por -1 (ternario).

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: de una frase, lista de palabras limpias + longitudes, y palabra más larga.

# %%
# Reto
# TODO
