# %% [markdown]
# # Archivos de texto
#
# ## Objetivos
# - open()
# - with
# - read/write
# - rutas relativas
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: escribir y leer

# %%
with open('demo.txt', 'w', encoding='utf-8') as f:
    f.write('linea1\nlinea2\n')

with open('demo.txt', 'r', encoding='utf-8') as f:
    print(f.read())

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Crea `mi_nombre.txt` y escribe tu nombre.
# 2. Lee `mi_nombre.txt` y muestra contenido.
# 3. Escribe 5 líneas numeradas en `lineas.txt`.
# 4. Lee `lineas.txt` y cuenta cuántas líneas tiene.
# 5. Añade una línea extra al final de `lineas.txt` (append).
# 6. Lee `lineas.txt` y muestra solo la primera línea.
# 7. Lee `lineas.txt` y muestra solo la última línea.
# 8. Crea `numeros.txt` con 10 números (uno por línea).
# 9. Lee `numeros.txt` y calcula la suma total.
# 10. Lee `numeros.txt` y cuenta cuántos son pares.

# %% [markdown]
# ### Ejercicio 1
# Crea `mi_nombre.txt` y escribe tu nombre.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Lee `mi_nombre.txt` y muestra contenido.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Escribe 5 líneas numeradas en `lineas.txt`.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Lee `lineas.txt` y cuenta cuántas líneas tiene.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Añade una línea extra al final de `lineas.txt` (append).

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Lee `lineas.txt` y muestra solo la primera línea.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Lee `lineas.txt` y muestra solo la última línea.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Crea `numeros.txt` con 10 números (uno por línea).

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Lee `numeros.txt` y calcula la suma total.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Lee `numeros.txt` y cuenta cuántos son pares.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: diario (añadir entrada / ver todo / salir).

# %%
# Reto
# TODO
