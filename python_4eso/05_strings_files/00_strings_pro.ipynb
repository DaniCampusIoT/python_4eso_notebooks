# %% [markdown]
# # Strings: métodos y f-strings
#
# ## Objetivos
# - split/strip/lower
# - in
# - f-strings
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: limpiar y formatear

# %%
texto = '  Hola Mundo  '
limpio = texto.strip().lower()
print(f'Texto limpio: {limpio}')

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Pide una frase y muéstrala sin espacios al principio y al final (strip).
# 2. Pide una frase y muéstrala en minúsculas (lower).
# 3. Pide una frase y muéstrala en mayúsculas (upper).
# 4. Pide una frase y cuenta cuántas letras 'a' tiene (count).
# 5. Divide una frase en palabras (split) y muestra la lista.
# 6. Muestra cuántas palabras tiene la frase.
# 7. Comprueba si una palabra contiene la letra 'e' (usa `in`).
# 8. Pide nombre y apellido y crea username nombre.apellido en minúsculas.
# 9. Mensaje con f-string que muestre un número con 2 decimales.
# 10. Comprueba si una palabra es palíndromo ignorando mayúsculas.

# %% [markdown]
# ### Ejercicio 1
# Pide una frase y muéstrala sin espacios al principio y al final (strip).

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Pide una frase y muéstrala en minúsculas (lower).

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Pide una frase y muéstrala en mayúsculas (upper).

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Pide una frase y cuenta cuántas letras 'a' tiene (count).

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Divide una frase en palabras (split) y muestra la lista.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Muestra cuántas palabras tiene la frase.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Comprueba si una palabra contiene la letra 'e' (usa `in`).

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Pide nombre y apellido y crea username nombre.apellido en minúsculas.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Mensaje con f-string que muestre un número con 2 decimales.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Comprueba si una palabra es palíndromo ignorando mayúsculas.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: normalizador de nombres → nombre completo, username y email sugerido.

# %%
# Reto
# TODO
