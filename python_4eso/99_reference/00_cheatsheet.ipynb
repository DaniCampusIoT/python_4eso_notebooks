# %% [markdown]
# # Cheatsheet Python (resumen rápido)
#
# ## Objetivos
# - Recordatorio rápido
# - Plantillas de código
# - Errores típicos
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: mini-recordatorio

# %%
print('if / for / while / listas / dicts / funciones / try-except / clases')

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Plantilla mínima de if/elif/else con ejemplo real.
# 2. Plantilla while para validar input.
# 3. Plantilla for range(1,N+1) con acumulador.
# 4. Plantilla recorrer lista y contar pares.
# 5. Plantilla recorrer diccionario con items().
# 6. Plantilla de función con return y docstring.
# 7. Plantilla try/except ValueError al convertir input.
# 8. 3 ejemplos de f-strings (decimales, texto, alineación).
# 9. 3 asserts para `es_par`.
# 10. Refactor: pide 3 notas y muestra media usando `media_3`.

# %% [markdown]
# ### Ejercicio 1
# Plantilla mínima de if/elif/else con ejemplo real.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Plantilla while para validar input.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Plantilla for range(1,N+1) con acumulador.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Plantilla recorrer lista y contar pares.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Plantilla recorrer diccionario con items().

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Plantilla de función con return y docstring.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Plantilla try/except ValueError al convertir input.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# 3 ejemplos de f-strings (decimales, texto, alineación).

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# 3 asserts para `es_par`.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Refactor: pide 3 notas y muestra media usando `media_3`.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: crea una chuleta de 1 página en Markdown con ejemplos copiables.

# %%
# Reto
# TODO
