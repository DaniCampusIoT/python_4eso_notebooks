# %% [markdown]
# # Crear tu propio módulo
#
# ## Objetivos
# - Crear .py reutilizable
# - Importar tu módulo
# - Separar funciones
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo guiado: crear utils.py y luego importarlo

# %%
# Ejemplo: from utils import es_par
# print(es_par(10))

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Crea `utils.py` con `es_par(n)`.
# 2. Importa `es_par` y pruébala con 3 valores.
# 3. Añade `cuadrado(n)` a utils.py y pruébala.
# 4. Añade `media(lista)` a utils.py y pruébala.
# 5. Crea `texto.py` con `limpia(s)` (strip+lower).
# 6. Importa `limpia` y úsala para normalizar un texto.
# 7. Añade `username(nombre, apellido)` a texto.py (nombre.apellido).
# 8. Crea mini-programa que combine limpia + username.
# 9. Markdown: ventajas de separar en módulos.
# 10. Organiza carpeta y comprueba imports.

# %% [markdown]
# ### Ejercicio 1
# Crea `utils.py` con `es_par(n)`.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Importa `es_par` y pruébala con 3 valores.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Añade `cuadrado(n)` a utils.py y pruébala.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Añade `media(lista)` a utils.py y pruébala.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Crea `texto.py` con `limpia(s)` (strip+lower).

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Importa `limpia` y úsala para normalizar un texto.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Añade `username(nombre, apellido)` a texto.py (nombre.apellido).

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Crea mini-programa que combine limpia + username.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Markdown: ventajas de separar en módulos.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Organiza carpeta y comprueba imports.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: crea paquete `miapp/` con __init__.py y un módulo, e importa miapp.saludar().

# %%
# Reto
# TODO
