# %% [markdown]
# # import y módulos
#
# ## Objetivos
# - import
# - from
# - alias
# - módulos estándar
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: math y random

# %%
import math, random
print(math.sqrt(144))
print(random.randint(1, 6))

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Importa math y calcula sqrt(81).
# 2. Importa math y calcula 2**10 (o pow).
# 3. Importa random y genera un número 1..10.
# 4. Genera 5 tiradas de dado (1..6) y guárdalas en lista.
# 5. Calcula la media de esas 5 tiradas.
# 6. Simula 100 tiradas y cuenta cuántas veces sale un 6.
# 7. Importa datetime y muestra la fecha de hoy.
# 8. Crea alias `import random as rnd` y úsalo.
# 9. Usa `from math import pi` y calcula área círculo radio 3.
# 10. Markdown: cuándo usar `import x` vs `from x import y`.

# %% [markdown]
# ### Ejercicio 1
# Importa math y calcula sqrt(81).

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Importa math y calcula 2**10 (o pow).

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Importa random y genera un número 1..10.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Genera 5 tiradas de dado (1..6) y guárdalas en lista.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Calcula la media de esas 5 tiradas.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Simula 100 tiradas y cuenta cuántas veces sale un 6.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Importa datetime y muestra la fecha de hoy.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Crea alias `import random as rnd` y úsalo.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Usa `from math import pi` y calcula área círculo radio 3.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Markdown: cuándo usar `import x` vs `from x import y`.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: 'piedra, papel o tijera' contra máquina usando random.

# %%
# Reto
# TODO
