# %% [markdown]
# # if / elif / else
#
# ## Objetivos
# - Ramas de decisión
# - Condiciones
# - Casos frontera
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: clasificar número

# %%
n = -3  # en clase: int(input('Número: '))
if n < 0:
    print('negativo')
elif n == 0:
    print('cero')
else:
    print('positivo')

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Pide una nota (0–10) e imprime 'aprobado' si >=5, si no 'suspenso'.
# 2. Amplía: para nota >=9 imprime 'sobresaliente', >=7 'notable', >=5 'bien', si no 'suspenso'.
# 3. Pide un número y di si es par o impar.
# 4. Pide una edad y di si es menor de edad (<18) o mayor de edad (>=18).
# 5. Pide un número y di si es múltiplo de 3, de 5, o de ninguno (usa elif).
# 6. Pide una temperatura y di si hace frío (<15), templado (15–24) o calor (>=25).
# 7. Pide 3 números y muestra cuál es el mayor (sin usar max).
# 8. Pide una palabra y di si está vacía (longitud 0) o no.
# 9. Pide un año y di si es bisiesto (regla: divisible por 4 y no por 100, o divisible por 400).
# 10. Pide una hora (0–23) y di si es mañana (6–11), tarde (12–19) o noche (20–5).

# %% [markdown]
# ### Ejercicio 1
# Pide una nota (0–10) e imprime 'aprobado' si >=5, si no 'suspenso'.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Amplía: para nota >=9 imprime 'sobresaliente', >=7 'notable', >=5 'bien', si no 'suspenso'.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Pide un número y di si es par o impar.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Pide una edad y di si es menor de edad (<18) o mayor de edad (>=18).

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Pide un número y di si es múltiplo de 3, de 5, o de ninguno (usa elif).

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Pide una temperatura y di si hace frío (<15), templado (15–24) o calor (>=25).

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Pide 3 números y muestra cuál es el mayor (sin usar max).

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Pide una palabra y di si está vacía (longitud 0) o no.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Pide un año y di si es bisiesto (regla: divisible por 4 y no por 100, o divisible por 400).

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Pide una hora (0–23) y di si es mañana (6–11), tarde (12–19) o noche (20–5).

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: 'selector de tarifa' por edad y estudiante. <12 paga 0, 12–17 paga 2, adulto 5, pero estudiantes adultos 3.

# %%
# Reto
# TODO
