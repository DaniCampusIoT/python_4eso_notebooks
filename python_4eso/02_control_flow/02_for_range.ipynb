# %% [markdown]
# # for y range()
#
# ## Objetivos
# - Bucle for
# - range(inicio, fin, paso)
# - Acumuladores
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: suma 1..N

# %%
N = 5
s = 0
for i in range(1, N+1):
    s += i
print('suma:', s)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Imprime del 1 al 10 con for.
# 2. Imprime del 0 al 20 de 2 en 2 con range(paso=2).
# 3. Imprime del 10 al 1 (descendente) con range.
# 4. Calcula la suma de 1..100 con un acumulador.
# 5. Calcula la suma de los pares entre 1 y 100.
# 6. Imprime la tabla del 7 (7x1..7x10).
# 7. Pide N y calcula la suma 1..N con for.
# 8. Pide N y cuenta cuántos números entre 1..N son múltiplos de 3.
# 9. Dibuja un rectángulo de asteriscos ancho 10 alto 3 (líneas).
# 10. Pide una palabra y muestra cada letra en una línea con for.

# %% [markdown]
# ### Ejercicio 1
# Imprime del 1 al 10 con for.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Imprime del 0 al 20 de 2 en 2 con range(paso=2).

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Imprime del 10 al 1 (descendente) con range.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Calcula la suma de 1..100 con un acumulador.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Calcula la suma de los pares entre 1 y 100.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Imprime la tabla del 7 (7x1..7x10).

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Pide N y calcula la suma 1..N con for.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Pide N y cuenta cuántos números entre 1..N son múltiplos de 3.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Dibuja un rectángulo de asteriscos ancho 10 alto 3 (líneas).

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Pide una palabra y muestra cada letra en una línea con for.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: pide N y dibuja un triángulo de asteriscos de altura N (1..N).

# %%
# Reto
# TODO
