# %% [markdown]
# # while y validación
#
# ## Objetivos
# - Bucle while
# - Contadores
# - Validación de entrada
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: pedir número válido (1..10) (simulado)

# %%
valores = [0, 12, 7]
i = 0
n = valores[i]
while not (1 <= n <= 10):
    i += 1
    n = valores[i]
print('OK:', n)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Cuenta del 1 al 10 usando while.
# 2. Cuenta del 10 al 1 usando while.
# 3. Pide un número y repite hasta que sea 0 (cuando sea 0, termina).
# 4. Pide una contraseña y repite hasta que sea 'python'.
# 5. Pide una nota y repite hasta que esté entre 0 y 10.
# 6. Suma números: pide números y suma hasta que el usuario escriba 0; al final muestra la suma.
# 7. Cuenta cuántos intentos necesita para escribir 'hola'.
# 8. Pide N y calcula factorial con while.
# 9. Imprime los números pares entre 2 y 20 usando while.
# 10. Pide un número y calcula cuántos dígitos tiene usando while (sin len).

# %% [markdown]
# ### Ejercicio 1
# Cuenta del 1 al 10 usando while.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Cuenta del 10 al 1 usando while.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Pide un número y repite hasta que sea 0 (cuando sea 0, termina).

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Pide una contraseña y repite hasta que sea 'python'.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Pide una nota y repite hasta que esté entre 0 y 10.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Suma números: pide números y suma hasta que el usuario escriba 0; al final muestra la suma.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Cuenta cuántos intentos necesita para escribir 'hola'.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Pide N y calcula factorial con while.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Imprime los números pares entre 2 y 20 usando while.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Pide un número y calcula cuántos dígitos tiene usando while (sin len).

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: menú en bucle: 1) sumar 2) restar 3) ver resultado 4) salir. Empieza con resultado=0.

# %%
# Reto
# TODO
