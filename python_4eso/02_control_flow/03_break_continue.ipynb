# %% [markdown]
# # break y continue
#
# ## Objetivos
# - Cortar bucles
# - Saltar iteraciones
# - Búsqueda
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: saltar y parar

# %%
for i in range(1, 21):
    if i % 3 == 0:
        continue
    if i == 13:
        break
    print(i)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Recorre 1..30 e imprime solo los que NO sean múltiplos de 5 (continue).
# 2. Recorre 1..100 y para cuando encuentres el primer múltiplo de 17 (break).
# 3. Recorre una lista y para cuando veas un número negativo.
# 4. Recorre 1..50 e imprime los múltiplos de 4 o de 6.
# 5. Pide números en while True y sal si el usuario escribe 'salir'.
# 6. En un for 1..20, salta los números entre 8 y 12 (inclusive).
# 7. Busca la primera letra 'a' en una palabra y muestra su índice (break).
# 8. Pide 5 notas; si alguna es inválida, ignórala (continue) y sigue hasta tener 5 válidas.
# 9. Recorre 1..100 y cuenta cuántos son primos (usa función auxiliar).
# 10. Recorre lista de palabras e imprime solo las que empiecen por vocal.

# %% [markdown]
# ### Ejercicio 1
# Recorre 1..30 e imprime solo los que NO sean múltiplos de 5 (continue).

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Recorre 1..100 y para cuando encuentres el primer múltiplo de 17 (break).

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Recorre una lista y para cuando veas un número negativo.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Recorre 1..50 e imprime los múltiplos de 4 o de 6.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Pide números en while True y sal si el usuario escribe 'salir'.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# En un for 1..20, salta los números entre 8 y 12 (inclusive).

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Busca la primera letra 'a' en una palabra y muestra su índice (break).

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Pide 5 notas; si alguna es inválida, ignórala (continue) y sigue hasta tener 5 válidas.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Recorre 1..100 y cuenta cuántos son primos (usa función auxiliar).

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Recorre lista de palabras e imprime solo las que empiecen por vocal.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: pide contraseñas hasta que una cumpla (>=8 y contiene un número). Usa continue con mensajes.

# %%
# Reto
# TODO
