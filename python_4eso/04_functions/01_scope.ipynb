# %% [markdown]
# # Scope (variables locales)
#
# ## Objetivos
# - Local vs global
# - Evitar globales
# - Funciones puras
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: variable local vs global

# %%
x = 10

def f():
    x = 3
    return x

print('global', x)
print('local', f())
print('global otra vez', x)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Global `mensaje='hola'` y función con local `mensaje='adios'`; imprime ambas.
# 2. Función `suma(a,b)` sin globales.
# 3. Lista global `datos=[1,2,3]` y función que devuelva nueva lista duplicada sin modificar original.
# 4. Demuestra que modificar lista dentro de función puede afectar si se hace in-place.
# 5. Función `añadir_elemento(lista,x)` que devuelva NUEVA lista con x añadido.
# 6. Función `incrementa(n)` que devuelva n+1 y úsala en bucle para generar secuencia.
# 7. Función media(lista) sin globales.
# 8. Función `normaliza_texto(s)` (strip+lower).
# 9. Markdown: por qué usar globales puede causar errores.
# 10. Refactoriza un fragmento para eliminar una global (ejemplo).

# %% [markdown]
# ### Ejercicio 1
# Global `mensaje='hola'` y función con local `mensaje='adios'`; imprime ambas.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Función `suma(a,b)` sin globales.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Lista global `datos=[1,2,3]` y función que devuelva nueva lista duplicada sin modificar original.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Demuestra que modificar lista dentro de función puede afectar si se hace in-place.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Función `añadir_elemento(lista,x)` que devuelva NUEVA lista con x añadido.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Función `incrementa(n)` que devuelva n+1 y úsala en bucle para generar secuencia.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Función media(lista) sin globales.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Función `normaliza_texto(s)` (strip+lower).

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Markdown: por qué usar globales puede causar errores.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Refactoriza un fragmento para eliminar una global (ejemplo).

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: mini-juego (adivina número) gestionando estado pasando parámetros (sin globales).

# %%
# Reto
# TODO
