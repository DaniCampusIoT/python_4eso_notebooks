# %% [markdown]
# # Autocomprobación con assert
#
# ## Objetivos
# - assert
# - tests simples
# - Casos borde
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: tests mínimos

# %%
def suma(a, b):
    return a + b

assert suma(2,3) == 5
assert suma(0,0) == 0
print('OK')

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Escribe `suma(a,b)` y añade 3 asserts.
# 2. Escribe `es_par(n)` y añade 4 asserts (incluye n=0).
# 3. `mayor(a,b)` con asserts a>b, a<b y a==b.
# 4. `area_rectangulo(ancho,alto)` con 3 asserts.
# 5. `media(lista)` con 2 asserts.
# 6. Caso borde para media: lista de un solo elemento.
# 7. `limpia_texto(s)` (strip+lower) + asserts.
# 8. `factorial(n)` (n>=0) + asserts para 0,1,5.
# 9. `contiene_numero(s)` True si hay algún dígito + asserts.
# 10. Markdown: “Qué es un caso borde” con 3 ejemplos.

# %% [markdown]
# ### Ejercicio 1
# Escribe `suma(a,b)` y añade 3 asserts.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Escribe `es_par(n)` y añade 4 asserts (incluye n=0).

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# `mayor(a,b)` con asserts a>b, a<b y a==b.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# `area_rectangulo(ancho,alto)` con 3 asserts.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# `media(lista)` con 2 asserts.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Caso borde para media: lista de un solo elemento.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# `limpia_texto(s)` (strip+lower) + asserts.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# `factorial(n)` (n>=0) + asserts para 0,1,5.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# `contiene_numero(s)` True si hay algún dígito + asserts.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Markdown: “Qué es un caso borde” con 3 ejemplos.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: implementa `es_primo(n)` y crea asserts para n<2, primos pequeños, no primos y 97.

# %%
# Reto
# TODO
