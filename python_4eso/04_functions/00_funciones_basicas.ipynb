# %% [markdown]
# # Funciones
#
# ## Objetivos
# - def
# - parámetros
# - return
# - reutilización
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: función simple

# %%
def area_rectangulo(ancho, alto):
    return ancho * alto

print(area_rectangulo(3, 4))

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Define `saluda(nombre)` que devuelva 'Hola, <nombre>'.
# 2. Define `es_par(n)` que devuelva True/False.
# 3. Define `cuadrado(n)` que devuelva n*n.
# 4. Define `mayor(a,b)` que devuelva el mayor de los dos.
# 5. Define `media_3(a,b,c)` que devuelva la media de 3 números.
# 6. Define `km_a_m(km)` que convierta km a metros.
# 7. Define `celsius_a_f(c)` que convierta Celsius a Fahrenheit.
# 8. Define `contar_letras(palabra)` que devuelva len(palabra).
# 9. Define `es_mayor_edad(edad)` que devuelva edad>=18.
# 10. Crea un programa que use 3 funciones anteriores para resolver un problema sin repetir código.

# %% [markdown]
# ### Ejercicio 1
# Define `saluda(nombre)` que devuelva 'Hola, <nombre>'.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Define `es_par(n)` que devuelva True/False.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Define `cuadrado(n)` que devuelva n*n.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Define `mayor(a,b)` que devuelva el mayor de los dos.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Define `media_3(a,b,c)` que devuelva la media de 3 números.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Define `km_a_m(km)` que convierta km a metros.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Define `celsius_a_f(c)` que convierta Celsius a Fahrenheit.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Define `contar_letras(palabra)` que devuelva len(palabra).

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Define `es_mayor_edad(edad)` que devuelva edad>=18.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Crea un programa que use 3 funciones anteriores para resolver un problema sin repetir código.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: conversor con menú usando funciones: 1) km→m 2) m→cm 3) °C→°F 4) salir.

# %%
# Reto
# TODO
