# %% [markdown]
# # Jupyter: normas y flujo de trabajo
#
# ## Objetivos
# - Entender qué es una celda (Markdown vs Código).
# - Ejecutar celdas en orden y reiniciar kernel.
# - Aprender el flujo de entrega (Restart & Run All).
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo 1: Markdown vs código
# Esta es una celda Markdown. La de abajo es de código.

# %%
print('Hola desde Jupyter')
2 + 2

# %% [markdown]
# ### Ejemplo 2: Errores y lectura del traceback
# Descomenta la línea para ver un error controlado.

# %%
x = 10
print('x =', x)
# print(y)  # y no existe → NameError

# %% [markdown]
# ### Ejemplo 3: Reiniciar y ejecutar todo
# Prueba: Kernel → Restart & Run All.

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Crea una celda Markdown con tu nombre, curso y la fecha.
# 2. Crea una celda de código que imprima: 'Estoy listo para programar'.
# 3. Crea una variable `nombre` y otra `edad` e imprímelas en una sola línea con f-string.
# 4. Crea una celda que calcule 10+5 y otra que calcule 10*5 (en celdas separadas).
# 5. Crea una variable `resultado` en una celda y úsala en otra celda para imprimir el doble.
# 6. Provoca un error intencional (por ejemplo, usar una variable no definida), y escribe en Markdown qué significa el error.
# 7. Arregla el error del ejercicio anterior sin borrar la celda: añade lo que falte.
# 8. Haz Kernel → Restart & Run All. Si algo falla, corrígelo hasta que funcione.
# 9. Cambia el nombre del notebook (desde Jupyter) para que siga este formato: `apellido1_nombre_00.ipynb`.
# 10. Crea una carpeta llamada `mis_pruebas` en el explorador de archivos de Jupyter y entra en ella.

# %% [markdown]
# ### Ejercicio 1
# Crea una celda Markdown con tu nombre, curso y la fecha.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Crea una celda de código que imprima: 'Estoy listo para programar'.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Crea una variable `nombre` y otra `edad` e imprímelas en una sola línea con f-string.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Crea una celda que calcule 10+5 y otra que calcule 10*5 (en celdas separadas).

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Crea una variable `resultado` en una celda y úsala en otra celda para imprimir el doble.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Provoca un error intencional (por ejemplo, usar una variable no definida), y escribe en Markdown qué significa el error.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Arregla el error del ejercicio anterior sin borrar la celda: añade lo que falte.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Haz Kernel → Restart & Run All. Si algo falla, corrígelo hasta que funcione.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Cambia el nombre del notebook (desde Jupyter) para que siga este formato: `apellido1_nombre_00.ipynb`.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Crea una carpeta llamada `mis_pruebas` en el explorador de archivos de Jupyter y entra en ella.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: crea un mini-notebook de presentación con 3 secciones Markdown y 2 celdas de código (input + salida con f-string). Debe funcionar con Restart & Run All.

# %%
# Reto
# TODO
