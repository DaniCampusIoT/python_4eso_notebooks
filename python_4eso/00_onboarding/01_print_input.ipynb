# %% [markdown]
# # print(), input() y conversiones
#
# ## Objetivos
# - Usar print()
# - Leer datos con input()
# - Convertir str→int/float y validar
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Lee los ejemplos y prueba a modificarlos.
# - Haz los 10 ejercicios.
# - Haz el reto si te queda tiempo.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo 1: input devuelve str

# %%
x = input('Escribe algo: ')
print('Tipo:', type(x))

# %% [markdown]
# ### Ejemplo 2: convertir a int

# %%
n = int(input('Número entero: '))
print('Doble:', n*2)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Pide un nombre por input() y saluda con print().
# 2. Pide dos números enteros y muestra su suma.
# 3. Pide un número entero y muestra su triple.
# 4. Pide una edad y muestra cuántos años tendrás dentro de 5 años.
# 5. Pide un precio (decimal) y muestra el precio con IVA (21%).
# 6. Pide una temperatura en °C (float) y conviértela a °F.
# 7. Pide dos números y muestra cuál es mayor (imprime un booleano a>b).
# 8. Pide una palabra y muestra su longitud con len().
# 9. Pide un número y muestra si es par (True/False) usando %.
# 10. Pide un número y muestra su cuadrado.

# %% [markdown]
# ### Ejercicio 1
# Pide un nombre por input() y saluda con print().

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Pide dos números enteros y muestra su suma.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Pide un número entero y muestra su triple.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Pide una edad y muestra cuántos años tendrás dentro de 5 años.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Pide un precio (decimal) y muestra el precio con IVA (21%).

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Pide una temperatura en °C (float) y conviértela a °F.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Pide dos números y muestra cuál es mayor (imprime un booleano a>b).

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Pide una palabra y muestra su longitud con len().

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Pide un número y muestra si es par (True/False) usando %.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Pide un número y muestra su cuadrado.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: pide nombre, edad y altura (m). Imprime resumen y calcula IMC suponiendo peso fijo 60 kg.

# %%
# Reto
# TODO
