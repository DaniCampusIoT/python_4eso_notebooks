# %% [markdown]
# # Depuración básica
#
# ## Objetivos
# - Leer tracebacks
# - Print-debugging
# - Casos límite
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: prints para entender qué pasa

# %%
def f(n):
    print('n=', n)
    return 10 / n

print(f(2))
# print(f(0))

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Crea una función con un bug (variable mal escrita) y observa el traceback.
# 2. Arregla el bug y explica en Markdown qué significaba el error.
# 3. Crea `media(lista)` que falle con lista vacía, provoca el fallo y observa.
# 4. Arregla media para lista vacía devolviendo 0 (o None) con mensaje.
# 5. Crea `maximo(lista)` y prueba con lista vacía (caso borde).
# 6. Añade prints dentro de un bucle para ver acumulador.
# 7. Programa que convierta input a int y falle; añade prints para ver qué llega.
# 8. Escribe 3 casos de prueba manuales y resultados esperados.
# 9. Usa asserts para detectar un error temprano.
# 10. Refactoriza un bloque en pasos y añade prints por paso.

# %% [markdown]
# ### Ejercicio 1
# Crea una función con un bug (variable mal escrita) y observa el traceback.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Arregla el bug y explica en Markdown qué significaba el error.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Crea `media(lista)` que falle con lista vacía, provoca el fallo y observa.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Arregla media para lista vacía devolviendo 0 (o None) con mensaje.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Crea `maximo(lista)` y prueba con lista vacía (caso borde).

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Añade prints dentro de un bucle para ver acumulador.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Programa que convierta input a int y falle; añade prints para ver qué llega.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Escribe 3 casos de prueba manuales y resultados esperados.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Usa asserts para detectar un error temprano.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Refactoriza un bloque en pasos y añade prints por paso.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: `cuenta_vocales(s)` que funcione con 'Hola','AEIOU','', 'murciélago'.

# %%
# Reto
# TODO
