# %% [markdown]
# # try/except
#
# ## Objetivos
# - Capturar errores
# - ValueError
# - Programas robustos
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: convertir a int con control de error

# %%
txt = 'abc'
try:
    n = int(txt)
    print('OK', n)
except ValueError:
    print('Eso no era un número')

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Pide un entero y captura ValueError si escriben texto.
# 2. Repite la petición hasta que sea válido.
# 3. Pide dos números y captura errores de conversión.
# 4. Función `leer_entero(mensaje)` que insiste hasta conseguir int.
# 5. Usa `leer_entero` para pedir 3 números y calcular media.
# 6. Función `dividir(a,b)` que capture ZeroDivisionError y devuelva None.
# 7. Pide a y b y usa dividir mostrando mensaje si b==0.
# 8. Intenta abrir archivo inexistente y captura FileNotFoundError.
# 9. Crea un archivo y léelo con with sin errores.
# 10. Markdown: por qué try/except debe cubrir lo mínimo posible.

# %% [markdown]
# ### Ejercicio 1
# Pide un entero y captura ValueError si escriben texto.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Repite la petición hasta que sea válido.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Pide dos números y captura errores de conversión.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Función `leer_entero(mensaje)` que insiste hasta conseguir int.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Usa `leer_entero` para pedir 3 números y calcular media.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Función `dividir(a,b)` que capture ZeroDivisionError y devuelva None.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Pide a y b y usa dividir mostrando mensaje si b==0.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Intenta abrir archivo inexistente y captura FileNotFoundError.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Crea un archivo y léelo con with sin errores.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Markdown: por qué try/except debe cubrir lo mínimo posible.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: conversor robusto (°C→°F o km→m), validando todo y sin romperse.

# %%
# Reto
# TODO
