# %% [markdown]
# # Proyecto 4: Puente a MicroPython (simulación sensores + LCD texto)
#
# ## Objetivos
# - Funciones
# - bucles
# - simular sensores
# - mostrar en “LCD” (texto)
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: sensor simulado

# %%
import random
def leer_temp():
    return round(random.uniform(18.0, 30.0), 1)
print(leer_temp())

# %% [markdown]
# ### Ejemplo: LCD texto (2 líneas)

# %%
linea1 = 'TEMP: 24.3C'
linea2 = 'HUM:  55%'
print('+' + '-'*14 + '+')
print('|' + linea1.ljust(14) + '|')
print('|' + linea2.ljust(14) + '|')
print('+' + '-'*14 + '+')

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Función `leer_temperatura()` float 18..30.
# 2. Función `leer_humedad()` int 30..80.
# 3. Función `formatea_lcd(temp, hum)` → 2 strings de 14 chars.
# 4. Imprime marco LCD + 2 líneas usando ljust.
# 5. Bucle que muestre 5 lecturas.
# 6. Guarda 5 lecturas en lista de tuplas (temp, hum).
# 7. Calcula medias desde histórico.
# 8. Muestra temperatura máxima registrada.
# 9. Cuenta cuántas humedades superan 60%.
# 10. Modo alerta: si temp>28 o hum>70 imprime ALERTA en 2ª línea.

# %% [markdown]
# ### Ejercicio 1
# Función `leer_temperatura()` float 18..30.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Función `leer_humedad()` int 30..80.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Función `formatea_lcd(temp, hum)` → 2 strings de 14 chars.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Imprime marco LCD + 2 líneas usando ljust.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Bucle que muestre 5 lecturas.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Guarda 5 lecturas en lista de tuplas (temp, hum).

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Calcula medias desde histórico.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Muestra temperatura máxima registrada.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Cuenta cuántas humedades superan 60%.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Modo alerta: si temp>28 o hum>70 imprime ALERTA en 2ª línea.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: menú: 1) lectura actual 2) histórico 3) resumen 4) salir.

# %%
# Reto
# TODO
