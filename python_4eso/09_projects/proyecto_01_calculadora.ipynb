# %% [markdown]
# # Proyecto 1: Calculadora con menú
#
# ## Objetivos
# - Menú
# - Funciones
# - Validación básica
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: estructura mínima de menú

# %%
op = ''
while op != '3':
    print('1) sumar')
    print('2) restar')
    print('3) salir')
    op = input('Elige: ')
print('Fin')

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Escribe menú: sumar, restar, multiplicar, dividir, salir.
# 2. Crea `leer_float(mensaje)`.
# 3. Crea `sumar(a,b)`.
# 4. Crea `restar(a,b)`.
# 5. Crea `multiplicar(a,b)`.
# 6. Crea `dividir(a,b)` con b==0.
# 7. Integra el menú para llamar a funciones.
# 8. Tras cada operación imprime resultado con 2 decimales.
# 9. Añade opción 'historial' (lista) y muéstralo.
# 10. Valida opción inválida con mensaje.

# %% [markdown]
# ### Ejercicio 1
# Escribe menú: sumar, restar, multiplicar, dividir, salir.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Crea `leer_float(mensaje)`.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Crea `sumar(a,b)`.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Crea `restar(a,b)`.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Crea `multiplicar(a,b)`.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Crea `dividir(a,b)` con b==0.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Integra el menú para llamar a funciones.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Tras cada operación imprime resultado con 2 decimales.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Añade opción 'historial' (lista) y muéstralo.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Valida opción inválida con mensaje.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: opción 'usar resultado anterior' como primer operando.

# %%
# Reto
# TODO
