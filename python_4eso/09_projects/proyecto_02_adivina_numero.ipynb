# %% [markdown]
# # Proyecto 2: Adivina el número
#
# ## Objetivos
# - random
# - bucles
# - comparaciones
# - contadores
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: randint

# %%
import random
secreto = random.randint(1,10)
print('Secreto demo:', secreto)

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Genera secreto 1..100.
# 2. Pide un intento (int).
# 3. Mientras no acierte, sigue pidiendo.
# 4. Si intento menor: 'más alto'.
# 5. Si intento mayor: 'más bajo'.
# 6. Cuenta intentos.
# 7. Al acertar, imprime mensaje con intentos.
# 8. Valida input no numérico.
# 9. Añade límite de intentos (10) y si se supera, pierde.
# 10. Al final, pregunta si quiere jugar otra vez (sí/no).

# %% [markdown]
# ### Ejercicio 1
# Genera secreto 1..100.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Pide un intento (int).

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Mientras no acierte, sigue pidiendo.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Si intento menor: 'más alto'.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Si intento mayor: 'más bajo'.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Cuenta intentos.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Al acertar, imprime mensaje con intentos.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Valida input no numérico.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Añade límite de intentos (10) y si se supera, pierde.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Al final, pregunta si quiere jugar otra vez (sí/no).

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: añade niveles (fácil 1..20, normal 1..100, difícil 1..500) y límites según nivel.

# %%
# Reto
# TODO
