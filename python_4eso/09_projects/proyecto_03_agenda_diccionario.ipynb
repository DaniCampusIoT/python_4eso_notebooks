# %% [markdown]
# # Proyecto 3: Agenda (diccionario + fichero)
#
# ## Objetivos
# - Diccionarios
# - CRUD
# - Guardar/cargar archivo
#
# ## Cómo trabajar
# - Ejecuta de arriba abajo.
# - Haz los 10 ejercicios.
# - Antes de entregar: Kernel → Restart & Run All.

# %%
# Bloque base (no borres esta celda)
from __future__ import annotations
import math
import random

# %% [markdown]
# ## Ejemplos previos

# %% [markdown]
# ### Ejemplo: agenda

# %%
agenda = {'ana': '600111222'}
print(agenda.get('ana'))

# %% [markdown]
# ## Actividades (10 ejercicios)
# 1. Crea diccionario `agenda` vacío.
# 2. Añadir/actualizar contacto.
# 3. Buscar contacto.
# 4. Borrar contacto.
# 5. Listar contactos.
# 6. Normaliza nombre (strip+lower) como clave.
# 7. Función guardar(agenda,fichero) nombre,teléfono por línea.
# 8. Función cargar(fichero) → dict.
# 9. Al iniciar, intenta cargar si existe.
# 10. Al salir, guarda automáticamente.

# %% [markdown]
# ### Ejercicio 1
# Crea diccionario `agenda` vacío.

# %%
# Ejercicio 1
# TODO

# %% [markdown]
# ### Ejercicio 2
# Añadir/actualizar contacto.

# %%
# Ejercicio 2
# TODO

# %% [markdown]
# ### Ejercicio 3
# Buscar contacto.

# %%
# Ejercicio 3
# TODO

# %% [markdown]
# ### Ejercicio 4
# Borrar contacto.

# %%
# Ejercicio 4
# TODO

# %% [markdown]
# ### Ejercicio 5
# Listar contactos.

# %%
# Ejercicio 5
# TODO

# %% [markdown]
# ### Ejercicio 6
# Normaliza nombre (strip+lower) como clave.

# %%
# Ejercicio 6
# TODO

# %% [markdown]
# ### Ejercicio 7
# Función guardar(agenda,fichero) nombre,teléfono por línea.

# %%
# Ejercicio 7
# TODO

# %% [markdown]
# ### Ejercicio 8
# Función cargar(fichero) → dict.

# %%
# Ejercicio 8
# TODO

# %% [markdown]
# ### Ejercicio 9
# Al iniciar, intenta cargar si existe.

# %%
# Ejercicio 9
# TODO

# %% [markdown]
# ### Ejercicio 10
# Al salir, guarda automáticamente.

# %%
# Ejercicio 10
# TODO

# %% [markdown]
# ## Reto
# Reto: buscar por prefijo (listar nombres que empiezan por prefijo).

# %%
# Reto
# TODO
